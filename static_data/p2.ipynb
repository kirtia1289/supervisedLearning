# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Command to tell Python to actually display the graphs
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from PIL import Image

# %%
data = pd.read_csv('/content/drive/My Drive/project/Basketball.csv')

# %%
data.shape
# Out:
# (61, 13)

# %%
data.size
# Out:
# 793

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Team                 61 non-null     object
#  1   Tournament           61 non-null     int64
#  2   Score                61 non-null     object
#  3   PlayedGames          61 non-null     object
#  4   WonGames             61 non-null     object
#  5   DrawnGames           61 non-null     object
#  6   LostGames            61 non-null     object
#  7   BasketScored         61 non-null     object
#  8   BasketGiven          61 non-null     object
#  9   TournamentChampion   61 non-null     object
#  10  Runner-up            61 non-null     object
#  11  TeamLaunch           61 non-null     object
#  12  HighestPositionHeld  61 non-null     int64
# dtypes: int64(2), object(11)
# memory usage: 6.3+ KB

# %%
data.describe
# Out:
# <bound method NDFrame.describe of        Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 0    Team 1          86  4385        2762     1647        552       563
# 1    Team 2          86  4262        2762     1581        573       608
# 2    Team 3          80  3442        2614     1241        598       775
# 3    Team 4          82  3386        2664     1187        616       861
# 4    Team 5          86  3368        2762     1209        633       920
# ..      ...         ...   ...         ...      ...        ...       ...
# 56  Team 57           1    34          38        8         10        20
# 57  Team 58           1    22          30        7          8        15
# 58  Team 59           1    19          30        7          5        18
# 59  Team 60           1    14          30        5          4        21
# 60  Team 61           1     -           -        -          -         -
#
#    BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# ...

# %%
data= data. replace('-','0' )
data
# Out:
#        Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 0    Team 1          86  4385        2762     1647        552       563
# 1    Team 2          86  4262        2762     1581        573       608
# 2    Team 3          80  3442        2614     1241        598       775
# 3    Team 4          82  3386        2664     1187        616       861
# 4    Team 5          86  3368        2762     1209        633       920
# ..      ...         ...   ...         ...      ...        ...       ...
# 56  Team 57           1    34          38        8         10        20
# 57  Team 58           1    22          30        7          8        15
# 58  Team 59           1    19          30        7          5        18
# 59  Team 60           1    14          30        5          4        21
# 60  Team 61           1     0           0        0          0         0
#
#    BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# ...

# %%
data.drop(60,inplace=True)
data
# Out:
#        Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 0    Team 1          86  4385        2762     1647        552       563
# 1    Team 2          86  4262        2762     1581        573       608
# 2    Team 3          80  3442        2614     1241        598       775
# 3    Team 4          82  3386        2664     1187        616       861
# 4    Team 5          86  3368        2762     1209        633       920
# 5    Team 6          73  2819        2408      990        531       887
# 6    Team 7          82  2792        2626      948        608      1070
# 7    Team 8          70  2573        2302      864        577       861
# 8    Team 9          58  2109        1986      698        522       766
# 9   Team 10          51  1884        1728      606        440       682
# 10  Team 11          45  1814        1530      563        392       575
# 11  Team 12          51  1789        1698      586        389       723
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of        Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 0    Team 1          86  4385        2762     1647        552       563
# 1    Team 2          86  4262        2762     1581        573       608
# 2    Team 3          80  3442        2614     1241        598       775
# 3    Team 4          82  3386        2664     1187        616       861
# 4    Team 5          86  3368        2762     1209        633       920
# 5    Team 6          73  2819        2408      990        531       887
# 6    Team 7          82  2792        2626      948        608      1070
# 7    Team 8          70  2573        2302      864        577       861
# 8    Team 9          58  2109        1986      698        522       766
# 9   Team 10          51  1884        1728      606        440       682
# 10  Team 11          45  1814        1530      563        392       575
# 11  Team 12          51  1789        1698      586        389       723
# ...

# %%
data.isnull().values.any()
# Out:
# False

# %%
dupes=data.duplicated()
sum(dupes)
# Out:
# 0

# %%
data
# Out:
#        Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 0    Team 1          86  4385        2762     1647        552       563
# 1    Team 2          86  4262        2762     1581        573       608
# 2    Team 3          80  3442        2614     1241        598       775
# 3    Team 4          82  3386        2664     1187        616       861
# 4    Team 5          86  3368        2762     1209        633       920
# 5    Team 6          73  2819        2408      990        531       887
# 6    Team 7          82  2792        2626      948        608      1070
# 7    Team 8          70  2573        2302      864        577       861
# 8    Team 9          58  2109        1986      698        522       766
# 9   Team 10          51  1884        1728      606        440       682
# 10  Team 11          45  1814        1530      563        392       575
# 11  Team 12          51  1789        1698      586        389       723
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 59
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Team                 60 non-null     object
#  1   Tournament           60 non-null     int64
#  2   Score                60 non-null     object
#  3   PlayedGames          60 non-null     object
#  4   WonGames             60 non-null     object
#  5   DrawnGames           60 non-null     object
#  6   LostGames            60 non-null     object
#  7   BasketScored         60 non-null     object
#  8   BasketGiven          60 non-null     object
#  9   TournamentChampion   60 non-null     object
#  10  Runner-up            60 non-null     object
#  11  TeamLaunch           60 non-null     object
#  12  HighestPositionHeld  60 non-null     int64
# dtypes: int64(2), object(11)
# memory usage: 6.6+ KB

# %%
data['TeamLaunch']= data['TeamLaunch'].apply(lambda x: x[0:4])

# %%
data
# Out:
#        Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 0    Team 1          86  4385        2762     1647        552       563
# 1    Team 2          86  4262        2762     1581        573       608
# 2    Team 3          80  3442        2614     1241        598       775
# 3    Team 4          82  3386        2664     1187        616       861
# 4    Team 5          86  3368        2762     1209        633       920
# 5    Team 6          73  2819        2408      990        531       887
# 6    Team 7          82  2792        2626      948        608      1070
# 7    Team 8          70  2573        2302      864        577       861
# 8    Team 9          58  2109        1986      698        522       766
# 9   Team 10          51  1884        1728      606        440       682
# 10  Team 11          45  1814        1530      563        392       575
# 11  Team 12          51  1789        1698      586        389       723
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 59
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Team                 60 non-null     object
#  1   Tournament           60 non-null     int64
#  2   Score                60 non-null     object
#  3   PlayedGames          60 non-null     object
#  4   WonGames             60 non-null     object
#  5   DrawnGames           60 non-null     object
#  6   LostGames            60 non-null     object
#  7   BasketScored         60 non-null     object
#  8   BasketGiven          60 non-null     object
#  9   TournamentChampion   60 non-null     object
#  10  Runner-up            60 non-null     object
#  11  TeamLaunch           60 non-null     object
#  12  HighestPositionHeld  60 non-null     int64
# dtypes: int64(2), object(11)
# memory usage: 6.6+ KB

# %%
#project p2.2

# %%
print("Data:",data.mean())
# Out:
# Data: Tournament              2.438333e+01
# Score                  7.309044e+182
# PlayedGames            4.603794e+184
# WonGames               2.745264e+151
# DrawnGames             9.209560e+143
# LostGames              9.393480e+156
# BasketScored           9.912650e+187
# BasketGiven            5.233852e+196
# TournamentChampion      5.541845e+60
# Runner-up               3.876446e+59
# TeamLaunch             3.215322e+237
# HighestPositionHeld     7.050000e+00
# dtype: float64

# %%
print("Data:",data.median())
# Out:
# Data: Tournament               12.0
# Score                   395.5
# PlayedGames             424.5
# WonGames                124.0
# DrawnGames               98.5
# LostGames               197.5
# BasketScored            444.0
# BasketGiven             632.5
# TournamentChampion        0.0
# Runner-up                 0.0
# TeamLaunch             1950.5
# HighestPositionHeld       6.0
# dtype: float64

# %%
print("Data_quantile(25%):",data.quantile(q=0.25))
# Out:
# Data_quantile(25%): Tournament             4.0
# HighestPositionHeld    3.0
# Name: 0.25, dtype: float64

# %%
	print(data['HighestPositionHeld'].mode())
# Out:
# 0    1
# dtype: int64

# %%
print(data['PlayedGames'].mode())
# Out:
# 0    2762
# 1      30
# dtype: object

# %%
print("Data_quantile(50%):",data.quantile(q=0.50))
# Out:
# Data_quantile(50%): Tournament             12.0
# HighestPositionHeld     6.0
# Name: 0.5, dtype: float64

# %%
print("Data_quantile(75%):",data.quantile(q=0.75))
# Out:
# Data_quantile(75%): Tournament             39.0
# HighestPositionHeld    10.0
# Name: 0.75, dtype: float64

# %%
data.describe()
# Out:
#        Tournament  HighestPositionHeld
# count   60.000000            60.000000
# mean    24.383333             7.050000
# std     26.884620             5.315232
# min      1.000000             1.000000
# 25%      4.000000             3.000000
# 50%     12.000000             6.000000
# 75%     39.000000            10.000000
# max     86.000000            20.000000

# %%
print(data.var())
# Out:
# Tournament             722.782768
# HighestPositionHeld     28.251695
# dtype: float64

# %%
print(data.std())
# Out:
# Tournament             26.884620
# HighestPositionHeld     5.315232
# dtype: float64

# %%
data.cov()
# Out:
#                      Tournament  HighestPositionHeld
# Tournament           722.782768          -101.172034
# HighestPositionHeld -101.172034            28.251695

# %%
data.skew()
# Out:
# Tournament             1.197176
# Score                  1.574104
# PlayedGames            1.123454
# WonGames               1.786067
# DrawnGames             0.984899
# LostGames              0.880596
# BasketScored           1.758058
# BasketGiven            0.958164
# TournamentChampion     4.734845
# Runner-up              4.321794
# TeamLaunch             0.682570
# HighestPositionHeld    0.832164
# dtype: float64

# %%
#univariate

# %%
plt.hist(df['WonGames'])
plt.xlabel('no of games won')
plt.ylabel('no of teams')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eeccc1d7a9b3> in <module>
# ----> 1 plt.hist(df['WonGames'])
#       2 plt.xlabel('no of games won')
#       3 plt.ylabel('no of teams')
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
data1=data["Score"]
#data2=data[Team]

# %%
data1
# Out:
# 0     4385
# 1     4262
# 2     3442
# 3     3386
# 4     3368
# 5     2819
# 6     2792
# 7     2573
# 8     2109
# 9     1884
# 10    1814
# 11    1789
# 12    1471
# 13    1416
# 14    1389
# 15    1351
# 16    1314
# 17    1174
# 18    1148
# 19    1020
# 20     970
# 21     667
# 22     662
# 23     606
# 24     553
# 25     538
# 26     510
# 27     445
# 28     421
# 29     416
# 30     375
# 31     353
# 32     343
# 33     293
# 34     285
# 35     277
# 36     242
# 37     230
# 38     190
# 39     188
# 40     168
# 41     150
# 42     148
# 43     132
# 44     107
# 45      96
# 46      91
# 47      83
# 48      81
# 49      76
# 50      71
# 51      56
# 52      52
# 53      42
# 54      40
# 55      35
# 56      34
# 57      22
# 58      19
# 59      14
# Name: Score, dtype: object

# %%
plt.figure(figsize=(30,5))# The bins argument creates class intervals. In this case we are creating 50 such intervals
plt.hist(data1, bins=25)
# Out:
# (array([3., 2., 3., 2., 2., 3., 2., 2., 3., 2., 2., 3., 2., 3., 2., 2., 3.,
#         2., 2., 3., 2., 2., 3., 2., 3.]),
#  array([ 0.  ,  2.36,  4.72,  7.08,  9.44, 11.8 , 14.16, 16.52, 18.88,
#         21.24, 23.6 , 25.96, 28.32, 30.68, 33.04, 35.4 , 37.76, 40.12,
#         42.48, 44.84, 47.2 , 49.56, 51.92, 54.28, 56.64, 59.  ]),
#  <a list of 25 Patch objects>)

# %%
len(data)
# Out:
# 60

# %%
data.isnull().sum()
# Out:
# Tournament             0
# Score                  0
# PlayedGames            0
# WonGames               0
# DrawnGames             0
# LostGames              0
# BasketScored           0
# BasketGiven            0
# TournamentChampion     0
# Runner-up              0
# TeamLaunch             0
# HighestPositionHeld    0
# dtype: int64

# %%
#details of the top 20 winning teams, also the teams with highest score
df_wongames= df.nlargest(20, ['WonGames'])

# %%
#TOP 20 TEAMS WITH HIGHEST SCORE AND MOST NUMBER OF MATCHES WON
sns.barplot(y=df_wongames['Team'], x= df_wongames['WonGames'])
plt.show()

# %%
#find if the teams with max number of matches won also has the max number of baskets scored
sns.lineplot('Team', 'WonGames', data=df_wongames.head(10), color='red')
sns.lineplot('Team', 'BasketScored', data=df_wongames.head(10), color='green')
sns.lineplot('Team', 'BasketGiven', data=df_wongames.head(10), color='orange')
sns.lineplot('Team', 'Score', data=df_wongames.head(10), color='black')
plt.grid()
plt.xticks(rotation=90)
plt.legend(labels=['games won', 'baskets scored', 'baskets given', 'score'])
plt.show()

# %%
#Teams who have been tournament champions for the max number of times
df.nlargest(10, 'TournamentChampion')

# %%
sns.scatterplot( 'TeamLaunch', 'Team', data=df_wongames)

# %%
#we can see that most of the top winning teams were launched in 1929-60s
df[df['TeamLaunch']>='2000']

# %%
sns.distplot(data)

# %%
sns.boxplot(df['WonGames'])

# %%
plt.hist(data1, bins=50)
# Out:
# (array([2., 1., 1., 1., 1., 2., 1., 1., 1., 1., 1., 2., 1., 1., 1., 1., 2.,
#         1., 1., 1., 1., 1., 2., 1., 1., 1., 1., 2., 1., 1., 1., 1., 1., 2.,
#         1., 1., 1., 1., 2., 1., 1., 1., 1., 1., 2., 1., 1., 1., 1., 2.]),
#  array([ 0.  ,  1.18,  2.36,  3.54,  4.72,  5.9 ,  7.08,  8.26,  9.44,
#         10.62, 11.8 , 12.98, 14.16, 15.34, 16.52, 17.7 , 18.88, 20.06,
#         21.24, 22.42, 23.6 , 24.78, 25.96, 27.14, 28.32, 29.5 , 30.68,
#         31.86, 33.04, 34.22, 35.4 , 36.58, 37.76, 38.94, 40.12, 41.3 ,
#         42.48, 43.66, 44.84, 46.02, 47.2 , 48.38, 49.56, 50.74, 51.92,
#         53.1 , 54.28, 55.46, 56.64, 57.82, 59.  ]),
#  <a list of 50 Patch objects>)

# %%
plt.axvline(data['WonGames'].mean(), color='m', linewidth=1)

# %%
sns.distplot(data1, hist=False)

# %%
sns.violinplot(data['HighestPositionHeld'])

# %%
plt.figure(figsize=(20,10)) # makes the plot wider
plt.hist(data['WonGames'], color='g') # plots a simple histogram
plt.axvline(data['WonGames'].mean(), color='m', linewidth=1)
plt.axvline(data['WonGames'].median(), color='b', linestyle='dashed', linewidth=1)
plt.axvline(data['WonGames'].mode()[0], color='w', linestyle='dashed', linewidth=1)

# %%
plt.hist(data['WonGames'], color='g')
# Out:
# (array([6., 6., 6., 5., 6., 6., 5., 6., 6., 8.]),
#  array([ 0. ,  5.7, 11.4, 17.1, 22.8, 28.5, 34.2, 39.9, 45.6, 51.3, 57. ]),
#  <a list of 10 Patch objects>)

# %%
sns.pairplot(data)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 59
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Tournament           60 non-null     int64
#  1   Score                60 non-null     object
#  2   PlayedGames          60 non-null     object
#  3   WonGames             60 non-null     object
#  4   DrawnGames           60 non-null     object
#  5   LostGames            60 non-null     object
#  6   BasketScored         60 non-null     object
#  7   BasketGiven          60 non-null     object
#  8   TournamentChampion   60 non-null     object
#  9   Runner-up            60 non-null     object
#  10  TeamLaunch           60 non-null     object
#  11  HighestPositionHeld  60 non-null     int64
# dtypes: int64(2), object(10)
# memory usage: 8.1+ KB

# %%
sns.scatterplot(data['Tournament'], data['HighestPositionHeld'])

# %%
sns.distplot(data, hist_kws=dict(cumulative=True), kde_kws=dict(cumulative=True))

# %%
data.corr()
# Out:
#                      Tournament  HighestPositionHeld
# Tournament             1.000000            -0.708071
# HighestPositionHeld   -0.708071             1.000000

# %%
sns.heatmap(data.corr(), annot=True)

# %%
sns.scatterplot(data['Tournament'], data['HighestPositionHeld'], hue=data['WonGames'], palette='Set2')
